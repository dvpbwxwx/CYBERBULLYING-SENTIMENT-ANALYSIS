# %%
pip install apify_client pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 80.4 MB/s eta 0:00:00
# ...

# %%
from apify_client import ApifyClient

client = ApifyClient("apify_api_9iuD2FBXexVJrd0yVg4uROiYzNMGbf3i0HR2")

run_input = {
    "commentsPerPost": 150,
    "excludePinnedPosts": False,
    "maxRepliesPerComment": 5,
    "postURLs": [
        "https://vt.tiktok.com/ZSDWeL11M/"
    ],
    "resultsPerPage": 100
}

run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)

items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
# Out:
# [apify.tiktok-comments-scraper runId:oWWDUqk1OAjtXKvg7] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:oWWDUqk1OAjtXKvg7] -> 2025-09-29T07:00:00.484Z ACTOR: Pulling Docker image of build EisyP6FKLpdtuhOcD from registry.
# [apify.tiktok-comments-scraper runId:oWWDUqk1OAjtXKvg7] -> 2025-09-29T07:00:00.486Z ACTOR: Creating Docker container.
# [apify.tiktok-comments-scraper runId:oWWDUqk1OAjtXKvg7] -> 2025-09-29T07:00:00.525Z ACTOR: Starting Docker container.
# [apify.tiktok-comments-scraper runId:oWWDUqk1OAjtXKvg7] -> 2025-09-29T07:00:00.771Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-comments-scraper runId:oWWDUqk1OAjtXKvg7] -> 2025-09-29T07:00:01.858Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.5"}
# ...

# %%
#Ubah data ke dataframe
import pandas as pd

df = pd.DataFrame(items)
df
# Out:
#                                            videoWebUrl  \
# 0    https://www.tiktok.com/@neryanau/video/7538402...
# 1    https://www.tiktok.com/@neryanau/video/7538402...
# 2    https://www.tiktok.com/@neryanau/video/7538402...
# 3    https://www.tiktok.com/@neryanau/video/7538402...
# 4    https://www.tiktok.com/@neryanau/video/7538402...
# ..                                                 ...
# 145  https://www.tiktok.com/@neryanau/video/7538402...
# 146  https://www.tiktok.com/@neryanau/video/7538402...
# 147  https://www.tiktok.com/@neryanau/video/7538402...
# 148  https://www.tiktok.com/@neryanau/video/7538402...
# 149  https://www.tiktok.com/@neryanau/video/7538402...
#
#                     submittedVideoUrl                             input  \
# 0    https://vt.tiktok.com/ZSDWeL11M/  https://vt.tiktok.com/ZSDWeL11M/
# 1    https://vt.tiktok.com/ZSDWeL11M/  https://vt.tiktok.com/ZSDWeL11M/
# 2    https://vt.tiktok.com/ZSDWeL11M/  https://vt.tiktok.com/ZSDWeL11M/
# ...

# %%
#Simpan data ke excel
df.to_excel('dataTiktok.xlsx', index=False)
